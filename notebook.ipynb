 Thank Transparent
 Thankful Triumph
 Thanksgiving Triumphant
 Therapeutic True
 Therapy Trust
 Thorough Trustworthy
 Thoughtful Trusty
 Thrill Truth
 Thrive Try
 Tidy Tuition
 Ultimate
 Ultra
 Unconditional
 Uncritical
 Understand
 Understanding
 Unequalled
 Unequivocal
 Unerring
 Unfetter
 Unflagging
 Ungrudging
 Upbeat
 Upgrade
 Uplift
 Upstanding
 Urbane
 Useful
 User-friendly
 Utmost
 Valid
 Validate
 Valuable
 Value
 Venerable
 Veracious
 Verify
 Versatile
 Very
 Viable
 Vibrant
 Virtue
 Virtuosity
 Virtuoso
 Virtuous
 Vitality
 Vivacious
 Vivid
 Warm Wise
 Warmth With
 Welcome Witty
 Well Won
 Wellbeing Wonder
 Wholehearted Wonderful
 Wholesome Wonderment
 Wholly Wondrous
 Will Workable
 Willing Worth
 Win Worthwhile
 Winner Worthy
 Winning Would
 Winsome Wow
 Wisdom
 Yearn
 Yes
 Yippee
 Young
 Youth
 Youthful
 Zeal
 Zealous
 Zest
"""

# %%
def clean(word_string):
    return word_string.replace("\n", "").split(" ")

# %%
len(list(set(clean(word_all))))

# %%
list(set(clean(word_all)))

# %%
import json

# %%
with open("word_english.json", "w") as f:
    json.dump(sorted(list(set(clean(word_all)))), f)

# %%
def get_translation(word, language_destination, language_source="en"):
    
    time.sleep(3)
    request_url = f"https://cuttlefish-asparagus.herokuapp.com/api?q={word}&src={language_source}&dst={language_destination}"
    response = json.loads(requests.get(request_url).text)
    
    if response.get("status_code"):
        while(response["status_code"] == 500):
            time.sleep(10)
            response = json.loads(requests.get(request_url).text)
            print(response, "trying again...")
        
    word_translated = ""
    if response.get("exact_matches"):
        if response["exact_matches"][0].get("translations"):
            word_translated = response["exact_matches"][0]["translations"][0]["text"]
            print(word_translated)
    else:
        print(response)
    
    return word_translated or None

# %%
def get_translation(word, language_destination, language_source="en"):
    
    translator = Translator()
    word_translated = translator.translate(word, dest=language_destination, src=language_source).text
    print(word, ">", word_translated)
    
    return word_translated or None

# %%
dict_translation = {
    "en": sorted(list(set(clean(word_all)))),
}

# %%
dict_translation["fr"] = [get_translation(word, "fr") for word in dict_translation["en"]]
# Out:
# Able > Capable
# Abundance > Abondance
# Accelerate > Accélérer
# Accept > Acceptez
# Acclaim > Acclamer
# Accolade > Accolade
# Accomplish > Accomplir
# Accord > Accord
# Accredit > Accréditer
# Accrue > Accruer
# Ace > As
# Achieve > Atteindre
# Action > action
# Activate > Activer
# Active > actif
# Add > Ajouter
# Addition > Une addition
# Adept > Expert
# Admirable > Admirable
# Adorable > Adorable
# Advance > Avance
# Advantage > Avantage
# Adventure > Aventure
# Affable > Affable
# Affirm > Affirmer
# Ageless > Sans âge
# Agree > Se mettre d'accord
# Agreeable > Agréable
# Aid > Aide
# Aim > Objectif
# Alacrity > Empressement
# Alert > Alerte
# Alight > Une lumière
# Alive > Vivant
# Always > Toujours
# Amaze > Étonner
# Amazing > Incroyable
# Ambition > Ambition
# Amiable > Aimable
# Amity > Amitié
# Amuse > Amuser
# Anew > Un nouveau
# Appealing > Attirant
# Applaud > Applaudir
# Appreciate > Apprécier
# Approve > Approuver
# Arouse > Susciter
# Ascend > Monter
# ...

# %%
from googletrans import Translator

translator = Translator()
translator.translate("bird", dest="fr", src="en").text
# Out:
# 'oiseau'
